# %% [markdown]
# # Feature Selection

# %% [markdown]
# #### Retrival the important features, selecting an important features is very important step before going to ML

# %% [markdown]
# - Droping the constant features (Regression and Classification)
# - Imformation Gain (Classification)
# - P-Value (Regression)
# - VIF (Regression)
# - Forword selection and backward selection (Regression and Classification)
# - Correlation with target column (Regression and Classification)

# %% [markdown]
# #### Feature selection methods

# %% [markdown]
# # 1) Variance thresold

# %% [markdown]
# ## [Droping the constant features (Regression and Classification)]

# %% [markdown]
# - based on variance we can decide the data is constant or varying
#
# - Data is not varying much means, data has same values
#
# - For example we have seen in loan dataset, loan term:360
#
# - Python by default will use variance=0, it will drop those fetaures which are having variance=0
#
# - Variance threshold is hyper parameter, we can keep threshold as any value
#
# - based on internal team discussion
#
# - we will drop those fetaure which are having <= threshold value

# %%
import pandas as pd 
dict1 = {"A":[100,200,300,400],
        "B":[1,2,3,4],
        "C":[10,20,30,40],
         "D":[10,10,10,10]}
df=pd.DataFrame(dict1)
df
# Out:
#      A  B   C   D
# 0  100  1  10  10
# 1  200  2  20  10
# 2  300  3  30  10
# 3  400  4  40  10

# %%
import sklearn

# %%
from sklearn.feature_selection import VarianceThreshold
vt = VarianceThreshold(threshold=0)
# Thresold variance value
# we have to drop the features based on thresold
vt.fit(df)
# Out:
# VarianceThreshold(threshold=0)

# %%
dir(vt)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_support_mask',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_sklearn_auto_wrap_output_keys',
#  '_transform',
#  '_validate_data',
#  '_validate_params',
#  'feature_names_in_',
#  'fit',
#  'fit_transform',
#  'get_feature_names_out',
#  'get_metadata_routing',
#  'get_params',
#  'get_support',
#  'inverse_transform',
#  'n_features_in_',
#  'set_output',
#  'set_params',
#  'threshold',
#  'transform',
#  'variances_']

# %%
vt.get_feature_names_out()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
vt.get_metadata_routing()
# Out:
# {}

# %%
vt.variances_
# Out:
# array([300.  ,   1.25,  30.  ,   0.  ])

# %%
vt.get_support()
# Out:
# array([ True,  True,  True, False])

# %%
vt.get_params()
# Out:
# {'threshold': 0}

# %%
type(vt.get_params())
# Out:
# dict

# %%
cols = ["A","B","C"]
df[cols]
# Out:
#      A  B   C
# 0  100  1  10
# 1  200  2  20
# 2  300  3  30
# 3  400  4  40

# %%
import pandas as pd

file_name = r"C:\Users\chand\Downloads\winequality_red.csv"
wine_df = pd.read_csv(file_name)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
import sklearn
from sklearn.feature_selection import VarianceThreshold
vt = VarianceThreshold(threshold=0.5)
vt.fit(wine_df)
# Out:
# VarianceThreshold(threshold=0.5)

# %%
vt.get_feature_names_out()
# Out:
# array(['fixed acidity', 'residual sugar', 'free sulfur dioxide',
#        'total sulfur dioxide', 'alcohol', 'quality'], dtype=object)

# %%
vt.variances_
# Out:
# array([3.02952057e+00, 3.20423261e-02, 3.79237511e-02, 1.98665392e+00,
#        2.21375732e-03, 1.09346457e+02, 1.08142564e+03, 3.55980179e-06,
#        2.38202742e-02, 2.87146470e-02, 1.13493717e+00, 6.51760540e-01])

# %%
vt.get_support()
# Out:
# array([ True, False, False,  True, False,  True,  True, False, False,
#        False,  True,  True])

# %%
vt.get_feature_names_out()
# Out:
# array(['fixed acidity', 'residual sugar', 'free sulfur dioxide',
#        'total sulfur dioxide', 'alcohol', 'quality'], dtype=object)

# %%
file_name = r"C:\Users\chand\Downloads\winequality_red.csv"
wine_df=pd.read_csv(file_name)
from sklearn.feature_selection import VarianceThreshold
vt=VarianceThreshold(threshold=0)
X=wine_df.drop('quality',axis=1) # select the input column
Y=wine_df['quality'] # select the output column
wine_df.shape,X.shape,Y.shape
vt.fit(X)
vt.variances_
vt.get_support
cols=vt.get_feature_names_out()
X[cols]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %% [markdown]
# ## Imformation gain

# %% [markdown]
# **Mutual info classify**

# %% [markdown]
# - It is a value estimating how much relationship/how much information about target variable
# - We dont want relation between input features
# - we want relation between input and ouput feature
# - 0 mean both variables are independent
# - Here will use entropy or KNN method based on joint probability

# %%
import sklearn
from sklearn.feature_selection import mutual_info_classif
mi = mutual_info_classif(X,Y)
mi
# Out:
# array([0.04322473, 0.13547013, 0.07666305, 0.02057842, 0.04198738,
#        0.0259428 , 0.06674222, 0.09395252, 0.01183508, 0.10123809,
#        0.17911006])

# %%
d = pd.DataFrame(mi,index=X.columns,
                columns=["MI"])
d
# Out:
#                             MI
# fixed acidity         0.043225
# volatile acidity      0.135470
# citric acid           0.076663
# residual sugar        0.020578
# chlorides             0.041987
# free sulfur dioxide   0.025943
# total sulfur dioxide  0.066742
# density               0.093953
# pH                    0.011835
# sulphates             0.101238
# alcohol               0.179110

# %%
sorted_data = d.sort_values(by="MI",ascending=False)
sorted_data
# Out:
#                             MI
# alcohol               0.179110
# volatile acidity      0.135470
# sulphates             0.101238
# density               0.093953
# citric acid           0.076663
# total sulfur dioxide  0.066742
# fixed acidity         0.043225
# chlorides             0.041987
# free sulfur dioxide   0.025943
# residual sugar        0.020578
# pH                    0.011835

# %%
con = sorted_data["MI"]>0.10

# %%
cols = sorted_data[con].index
cols
# Out:
# Index(['alcohol', 'volatile acidity', 'sulphates'], dtype='object')

# %%
d = pd.DataFrame(mi,index=X.columns,
                columns=["MI"])
d
# Out:
#                             MI
# fixed acidity         0.043225
# volatile acidity      0.135470
# citric acid           0.076663
# residual sugar        0.020578
# chlorides             0.041987
# free sulfur dioxide   0.025943
# total sulfur dioxide  0.066742
# density               0.093953
# pH                    0.011835
# sulphates             0.101238
# alcohol               0.179110
